# %% [markdown]
# # 简单测试Notebook

# %%
# 导入必要的库
import os
import sys
import pandas as pd
import subprocess

# %%
# 检查当前工作目录
print(f'当前工作目录: {os.getcwd()}')

# 检查项目结构
project_dir = 'movie_box_office_analysis'
print(f'项目目录存在: {os.path.exists(project_dir)}')
