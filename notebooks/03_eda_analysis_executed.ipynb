# %% [markdown]
# # 03_eda_analysis
#
# 本笔记本用于执行电影数据的探索性数据分析(EDA)，包括数据分布、相关性分析、趋势分析等。

# %%
# 导入必要的库
import os
import sys

# %% [markdown]
# ## 1. 检查项目结构

# %%
# 检查当前工作目录
print(f'当前工作目录: {os.getcwd()}')

# 检查项目结构
project_dir = '..'
print('项目结构:')
for root, dirs, files in os.walk(project_dir):
    level = root.replace(project_dir, '').count(os.sep)
    indent = ' ' * 2 * level
    print(f'{indent}{os.path.basename(root)}/')
    subindent = ' ' * 2 * (level + 1)
    for file in files[:5]:  # 只显示前5个文件
        print(f'{subindent}{file}')
    if len(files) > 5:
        print(f'{subindent}... 等 {len(files) - 5} 个文件')
# Out:
# 当前工作目录: C:\羊驼\pro\analysis\movie_box_office_analysis\notebooks
# 项目结构:
# ../
#   .editorconfig
#   .flake8
#   .gitignore
#   .markdownlint.json
#   .pylintrc
#   ... 等 14 个文件
#   .git/
#     COMMIT_EDITMSG
#     config
#     description
#     FETCH_HEAD
#     HEAD
#     ... 等 1 个文件
#     hooks/
#       applypatch-msg.sample
#       commit-msg.sample
#       fsmonitor-watchman.sample
#       post-update.sample
#       pre-applypatch.sample
#       ... 等 9 个文件
#     info/
#       exclude
#     logs/
#       HEAD
#       refs/
#         heads/
#           master
#         remotes/
#           origin/
#             main
#     objects/
#       08/
#         76b538d98c829642ab67af2d090243531bb64e
#         fcf46bb7405c6a5ce144cfea59a6da91334639
#       10/
#         1949aefabe9a83419aade8753b18af35f05ba4
#       12/
#         97c4c9c24467baf29d2433442222fa2d9ab5a7
#       13/
#         ce30a3a6848c27e6d418d5a41ffae8668b675d
#       15/
#         45e62bd536257879557de49217ec36f4115810
#       17/
#         27ce89b129480be0fd4df76c80327148ac4002
#       18/
#         466df860bda94f6bbd2f5db3436a70a9aefd0f
#       1a/
#         72769a49ad2d37717e73f9845964677bb5efda
#       1c/
#         8b5f5b6842b96629f6b97af43e35047db2ca0e
#       1d/
#         2546bf3aebcc005cca694532b7870d7a8451cf
#         90fed1e4c8708de5e32ea8fc657a192e052a48
#       21/
#         6dc998f001e28be5f8dbdc8b48990c7d078341
#       22/
#         fb2aadbddc112d8bbfe55fc19d588451f6999f
#       25/
#         605f2816ee7af05a32b7ece745ee395d88be90
#       29/
#         aed0701e631d763b8aa2e8b1f8db010cc37e8b
#         b2afdbd8aaaab5f735b9e366e17e455c603da2
#       2a/
#         98cbcb36695fe1ebe78237139df318e5eae657
#       32/
#         2d1278585cb4597adbb36594851edf18b10ecc
#       37/
#         c47c1db4c5c04ef4d73beca966565ff7c20233
#       3b/
#         bbeb2301a2bfe697d678e44171df92f1c0c3ff
#         e0669d79696219aa55d5e355f6f4e8e4ecb722
#       3d/
#         2ffd737a24c58c3385c5ae712e1fd83f47f126
#       3e/
#         a3ea91d153dcde8f998467598870e4d6eb56c5
#       42/
#         9122c162333967d81f0382dd6517950c5e9e0e
#         b4224704d6d6265e76bc89cf6cf0a670fb9503
#       44/
#         986a1dc46a018c9cbab27036443c7ae3849084
#       45/
#         553c3c99042bbeb7b6176b461551cc46c3d488
#       46/
#         4582e9be81d5129fdf000ff774b0208562078d
#         4fcb93685f3746eebcbc71d525ae65a2c62148
#       48/
#         1c43a39fc3b73b62b91207bd4d072df72910ea
#       4b/
#         de10e4cf8dd46d5e8ebf3df460fa76b942c6d6
#       4c/
#         7dbf9ada77a93c2b8b02b85409d97d5e1f450c
#       4d/
#         4162749bfbc465dd527dc239e2fca63b6ff9d0
#         532971b2a6a8cbe3a7b98740c5527f016daf1e
#       4e/
#         0648ae29d92b6478c2e4dcb819457ea235274b
#       57/
#         37f26be155ffd122b983dc749f182111149dbf
#       5b/
#         58e8ce584004d3825c1c4e22fb9a37e6c8053c
#       5c/
#         c49829364823874f3b2300ca0d893d97c7f875
#       5d/
#         4c9a898b7733ae785964286950fa2dbb02d95c
#       5f/
#         b5f9cd4c44c15e2d7c3cbcd502d5e5407d9e79
#       60/
#         392c662eb33bcefbc9446aa86f2fe131a58a51
#       63/
#         e69399a6f703c05bde6b7fe5cdd0d059e5bf5a
#       68/
#         52379cdfc9df3df7417ba94ea7d9cbefab8d6a
#       69/
#         a8118c9cf16f69e1ba4d1ede57af14cd03ca76
#       6b/
#         87b9b3154ec8f4b4f6d31ca766a814e263ac7d
#         bf976be447c9417e037fe31ef482f83719f958
#       6f/
#         eaa44ddaa1fba752b8a2f53b8d00e12fdff6cd
#       70/
#         c8a0e7e238eddd2a947ed7e017a0a3976eb939
#         dd87a284d8ba4250c4ddb8fdef2c40f33fe367
#       72/
#         4300eb5f790124542a0847c8b3a924df071cdd
#       73/
#         aca866d258fd56ddc92ae26d1d6136064a1e29
#       74/
#         0396794b7936c61b9e07e25a9e337385008e7d
#       75/
#         eedb47895a47e6f6ad926b7c315c7f0a361a3c
#       77/
#         65fb1d71359fa4d774d76a206bf5d3d8be35c7
#       7c/
#         53f559257e14d440626297c3a6a7b365a575e8
#       7e/
#         e645728a94534858c25efe980c91eaf1d44d82
#       80/
#         11b233e16d64e803b3738e3585d2a8428cf92a
#       81/
#         aa54b28d1dc2856fd32d0a6ecea087933bfdd9
#       8b/
#         bb2d44fef5bf694790f440da84d5081e4067a9
#       8d/
#         6de57af54c516ebde7cbcbd270330fb86cfdd6
#         eba4bc15ce3ea36282b5050b72bda54cd565dc
#       8f/
#         f919acdb1edb362c6873da5b87fb76fc5b532d
#       93/
#         b36733b922ba7a27571584978f5ffbcb0a1ffd
#       97/
#         e9f9fde95375a0f5684186f1aff3fd04266331
#       98/
#         99c8e2507e3131b2ab69e42e28a643d7ce6fe1
#       99/
#         ed5580d397be23dcddae6de3475e3bf0aecddf
#       9b/
#         169f37ed4cc11e692e1e87d3697628492a7e6c
#         fb11cdd0d16348be66836a48279d24de8404ea
#       a0/
#         ca0ce12a4ec908692c863ad0b0280b0a1cb7e8
#       a5/
#         17fe3a0b93d2b16841f605de1d001f41116c0b
#       a9/
#         58a939ddfb3419c9be55348a1c1bc2b61523fd
#         b9cbf9a6a7075be5bf9bb25ab3422ba006cdcf
#       ac/
#         adc457a3425d53d8c52d34123d6074cb7e9994
#       ad/
#         49add2dbf80a87758dfb19208bf4f6bb243830
#         d83d3f99e19357e1bbc021a766180acefe2221
#       af/
#         eceb8672d99051d4351b019875b23e9d4d2cdf
#       b9/
#         28386a8cb298714f1566f928951d46040ff68e
#       be/
#         35e89cc1cdc31059703a8c45d31bae8ec9fcf7
#       c0/
#         5bc3835be87313305effed8bcf88415657f3fe
#         7f0950acf4509e873db2dd9666101aeb36c8fc
#       c2/
#         c5a45f0daf94ece549043a86527279d695e70c
#       c3/
#         100e6e1cea085e596d83c7c68a4f0f451cdfb0
#       cd/
#         8fbcf5fe98fa7f0c31271411abeb560be0573b
#         c32355a7c0b46e5f46b71ce10f413872063421
#       ce/
#         dc82b25aa998c8770aff51fb36831c81652fbc
#       d5/
#         ac4d9fca66001c2decf0f4cc80f7ac47d0cc26
#       dc/
#         cc7c1b1549c2eb240a1d18a4ccf41649eb860b
#       dd/
#         2233419156dfbad713733d5ce711c805f2d56a
#       df/
#         62749a121730a5f40ff04ea968775d269e0a8b
#       e1/
#         e01f75102ef3b6cd7f00c21ee3600f014a8839
#       e3/
#         dfffece47259574fa53c12a586e750bc53f37f
#       e5/
#         b9ff53b78da5114cd964fd3a54fcbd67a7f405
#       e6/
#         3cb928bd72c0d826c967ffc82a20c76aa8f3b1
#       e8/
#         2abdd27bc2e814aa7b2c732db4fb20a6a185f1
#         7f8dbc3c5d6b6ddbf5c2dd3124ba10a9268197
#       e9/
#         11e48f311b1e2950398af5c8bed725501c2a6d
#       eb/
#         afa821af27ea2bacbe9703fee33247b1aec54b
#       ee/
#         de765647b2829cb321834fa7dbdf61fe73c4d3
#       fa/
#         056c92efe69be64f10e288ab3f72d87b3f35b7
#       fe/
#         92f9c0bf6def5e51628aa9af8655cc0e258ab2
#         fefebb0d7e4b0153e5c5ee4439ec768d6ea2ed
#       ff/
#         04f8e680bed9174695b64d7725e0a46bfc6b4e
#       info/
#       pack/
#         pack-e0d1bf018674de1e2e138764ea778cdf56fef062.idx
#         pack-e0d1bf018674de1e2e138764ea778cdf56fef062.pack
#         pack-e0d1bf018674de1e2e138764ea778cdf56fef062.rev
#     refs/
#       heads/
#         master
#       remotes/
#         origin/
#           main
#       tags/
#   .mypy_cache/
#     .gitignore
#     CACHEDIR.TAG
#     missing_stubs
#     3.13/
#       @plugins_snapshot.json
#       abc.data.json
#       abc.meta.json
#       argparse.data.json
#       argparse.meta.json
#       ... 等 316 个文件
#       aiohappyeyeballs/
#         impl.data.json
#         impl.meta.json
#         types.data.json
#         types.meta.json
#         utils.data.json
#         ... 等 5 个文件
#       aiohttp/
#         abc.data.json
#         abc.meta.json
#         base_protocol.data.json
#         base_protocol.meta.json
#         client.data.json
#         ... 等 87 个文件
#         _websocket/
#           helpers.data.json
#           helpers.meta.json
#           models.data.json
#           models.meta.json
#           reader.data.json
#           ... 等 7 个文件
#       aiosignal/
#         __init__.data.json
#         __init__.meta.json
#       alembic/
#         command.data.json
#         command.meta.json
#         config.data.json
#         config.meta.json
#         context.data.json
#         ... 等 7 个文件
#         autogenerate/
#           api.data.json
#           api.meta.json
#           compare.data.json
#           compare.meta.json
#           render.data.json
#           ... 等 5 个文件
#         ddl/
#           base.data.json
#           base.meta.json
#           impl.data.json
#           impl.meta.json
#           mssql.data.json
#           ... 等 13 个文件
#         operations/
#           base.data.json
#           base.meta.json
#           batch.data.json
#           batch.meta.json
#           ops.data.json
#           ... 等 7 个文件
#         runtime/
#           environment.data.json
#           environment.meta.json
#           migration.data.json
#           migration.meta.json
#           __init__.data.json
#           ... 等 1 个文件
#         script/
#           base.data.json
#           base.meta.json
#           revision.data.json
#           revision.meta.json
#           write_hooks.data.json
#           ... 等 3 个文件
#         util/
#           compat.data.json
#           compat.meta.json
#           editor.data.json
#           editor.meta.json
#           exc.data.json
#           ... 等 11 个文件
#       annotated_doc/
#         main.data.json
#         main.meta.json
#         __init__.data.json
#         __init__.meta.json
#       annotated_types/
#         __init__.data.json
#         __init__.meta.json
#       anyio/
#         from_thread.data.json
#         from_thread.meta.json
#         lowlevel.data.json
#         lowlevel.meta.json
#         to_thread.data.json
#         ... 等 3 个文件
#         abc/
#           _eventloop.data.json
#           _eventloop.meta.json
#           _resources.data.json
#           _resources.meta.json
#           _sockets.data.json
#           ... 等 11 个文件
#         streams/
#           memory.data.json
#           memory.meta.json
#           stapled.data.json
#           stapled.meta.json
#           tls.data.json
#           ... 等 3 个文件
#         _core/
#           _contextmanagers.data.json
#           _contextmanagers.meta.json
#           _eventloop.data.json
#           _eventloop.meta.json
#           _exceptions.data.json
#           ... 等 25 个文件
#       asttokens/
#         astroid_compat.data.json
#         astroid_compat.meta.json
#         asttokens.data.json
#         asttokens.meta.json
#         line_numbers.data.json
#         ... 等 7 个文件
#       asyncio/
#         base_events.data.json
#         base_events.meta.json
#         base_futures.data.json
#         base_futures.meta.json
#         constants.data.json
#         ... 等 45 个文件
#       attr/
#         converters.data.json
#         converters.meta.json
#         exceptions.data.json
#         exceptions.meta.json
#         filters.data.json
#         ... 等 13 个文件
#       attrs/
#         __init__.data.json
#         __init__.meta.json
#       bs4/
#         css.data.json
#         css.meta.json
#         dammit.data.json
#         dammit.meta.json
#         element.data.json
#         ... 等 15 个文件
#         builder/
#           _html5lib.data.json
#           _html5lib.meta.json
#           _htmlparser.data.json
#           _htmlparser.meta.json
#           _lxml.data.json
#           ... 等 3 个文件
#       chardet/
#         big5freq.data.json
#         big5freq.meta.json
#         big5prober.data.json
#         big5prober.meta.json
#         chardistribution.data.json
#         ... 等 81 个文件
#       charset_normalizer/
#         api.data.json
#         api.meta.json
#         cd.data.json
#         cd.meta.json
#         constant.data.json
#         ... 等 13 个文件
#       click/
#         core.data.json
#         core.meta.json
#         decorators.data.json
#         decorators.meta.json
#         exceptions.data.json
#         ... 等 25 个文件
#       collections/
#         abc.data.json
#         abc.meta.json
#         __init__.data.json
#         __init__.meta.json
#       colorlog/
#         escape_codes.data.json
#         escape_codes.meta.json
#         formatter.data.json
#         formatter.meta.json
#         wrappers.data.json
#         ... 等 3 个文件
#       concurrent/
#         __init__.data.json
#         __init__.meta.json
#         futures/
#           process.data.json
#           process.meta.json
#           thread.data.json
#           thread.meta.json
#           _base.data.json
#           ... 等 3 个文件
#       confection/
#         util.data.json
#         util.meta.json
#         __init__.data.json
#         __init__.meta.json
#       ctypes/
#         wintypes.data.json
#         wintypes.meta.json
#         _endian.data.json
#         _endian.meta.json
#         __init__.data.json
#         ... 等 1 个文件
#       cycler/
#         __init__.data.json
#         __init__.meta.json
#       email/
#         charset.data.json
#         charset.meta.json
#         contentmanager.data.json
#         contentmanager.meta.json
#         errors.data.json
#         ... 等 17 个文件
#       encodings/
#         aliases.data.json
#         aliases.meta.json
#         __init__.data.json
#         __init__.meta.json
#       executing/
#         executing.data.json
#         executing.meta.json
#         version.data.json
#         version.meta.json
#         _exceptions.data.json
#         ... 等 9 个文件
#       fastapi/
#         applications.data.json
#         applications.meta.json
#         background.data.json
#         background.meta.json
#         concurrency.data.json
#         ... 等 31 个文件
#         dependencies/
#           models.data.json
#           models.meta.json
#           utils.data.json
#           utils.meta.json
#           __init__.data.json
#           ... 等 1 个文件
#         middleware/
#           asyncexitstack.data.json
#           asyncexitstack.meta.json
#           __init__.data.json
#           __init__.meta.json
#         openapi/
#           constants.data.json
#           constants.meta.json
#           docs.data.json
#           docs.meta.json
#           models.data.json
#           ... 等 5 个文件
#         security/
#           api_key.data.json
#           api_key.meta.json
#           base.data.json
#           base.meta.json
#           http.data.json
#           ... 等 9 个文件
#         _compat/
#           main.data.json
#           main.meta.json
#           may_v1.data.json
#           may_v1.meta.json
#           model_field.data.json
#           ... 等 9 个文件
#       filelock/
#         asyncio.data.json
#         asyncio.meta.json
#         version.data.json
#         version.meta.json
#         _api.data.json
#         ... 等 13 个文件
#       frozenlist/
#         __init__.data.json
#         __init__.meta.json
#       html/
#         entities.data.json
#         entities.meta.json
#         parser.data.json
#         parser.meta.json
#         __init__.data.json
#         ... 等 1 个文件
#       http/
#         client.data.json
#         client.meta.json
#         cookiejar.data.json
#         cookiejar.meta.json
#         cookies.data.json
#         ... 等 3 个文件
#       huggingface_hub/
#         community.data.json
#         community.meta.json
#         constants.data.json
#         constants.meta.json
#         errors.data.json
#         ... 等 51 个文件
#         commands/
#           _cli_utils.data.json
#           _cli_utils.meta.json
#           __init__.data.json
#           __init__.meta.json
#         inference/
#           _client.data.json
#           _client.meta.json
#           _common.data.json
#           _common.meta.json
#           __init__.data.json
#           ... 等 1 个文件
#           _generated/
#             _async_client.data.json
#             _async_client.meta.json
#             __init__.data.json
#             __init__.meta.json
#             types/
#               audio_classification.data.json
#               audio_classification.meta.json
#               audio_to_audio.data.json
#               audio_to_audio.meta.json
#               automatic_speech_recognition.data.json
#               ... 等 63 个文件
#           _mcp/
#             agent.data.json
#             agent.meta.json
#             constants.data.json
#             constants.meta.json
#             mcp_client.data.json
#             ... 等 7 个文件
#           _providers/
#             black_forest_labs.data.json
#             black_forest_labs.meta.json
#             cerebras.data.json
#             cerebras.meta.json
#             clarifai.data.json
#             ... 等 39 个文件
#         serialization/
#           _base.data.json
#           _base.meta.json
#           _dduf.data.json
#           _dduf.meta.json
#           _tensorflow.data.json
#           ... 等 5 个文件
#         utils/
#           endpoint_helpers.data.json
#           endpoint_helpers.meta.json
#           insecure_hashlib.data.json
#           insecure_hashlib.meta.json
#           logging.data.json
#           ... 等 51 个文件
#       idna/
#         core.data.json
#         core.meta.json
#         idnadata.data.json
#         idnadata.meta.json
#         intranges.data.json
#         ... 等 5 个文件
#       importlib/
#         abc.data.json
#         abc.meta.json
#         machinery.data.json
#         machinery.meta.json
#         readers.data.json
#         ... 等 11 个文件
#         metadata/
#           _meta.data.json
#           _meta.meta.json
#           __init__.data.json
#           __init__.meta.json
#         resources/
#           abc.data.json
#           abc.meta.json
#           _common.data.json
#           _common.meta.json
#           _functional.data.json
#           ... 等 3 个文件
#       IPython/
#         display.data.json
#         display.meta.json
#         paths.data.json
#         paths.meta.json
#         __init__.data.json
#         ... 等 1 个文件
#         core/
#           alias.data.json
#           alias.meta.json
#           application.data.json
#           application.meta.json
#           async_helpers.data.json
#           ... 等 87 个文件
#           magics/
#             ast_mod.data.json
#             ast_mod.meta.json
#             auto.data.json
#             auto.meta.json
#             basic.data.json
#             ... 等 27 个文件
#         extensions/
#           storemagic.data.json
#           storemagic.meta.json
#           __init__.data.json
#           __init__.meta.json
#         external/
#           pickleshare.data.json
#           pickleshare.meta.json
#           __init__.data.json
#           __init__.meta.json
#         lib/
#           clipboard.data.json
#           clipboard.meta.json
#           display.data.json
#           display.meta.json
#           pretty.data.json
#           ... 等 3 个文件
#         terminal/
#           debugger.data.json
#           debugger.meta.json
#           embed.data.json
#           embed.meta.json
#           interactiveshell.data.json
#           ... 等 11 个文件
#           pt_inputhooks/
#             __init__.data.json
#             __init__.meta.json
#           shortcuts/
#             auto_match.data.json
#             auto_match.meta.json
#             auto_suggest.data.json
#             auto_suggest.meta.json
#             filters.data.json
#             ... 等 3 个文件
#         testing/
#           skipdoctest.data.json
#           skipdoctest.meta.json
#           __init__.data.json
#           __init__.meta.json
#         utils/
#           capture.data.json
#           capture.meta.json
#           contexts.data.json
#           contexts.meta.json
#           data.data.json
#           ... 等 57 个文件
#       jinja2/
#         async_utils.data.json
#         async_utils.meta.json
#         bccache.data.json
#         bccache.meta.json
#         compiler.data.json
#         ... 等 39 个文件
#       json/
#         decoder.data.json
#         decoder.meta.json
#         encoder.data.json
#         encoder.meta.json
#         __init__.data.json
#         ... 等 1 个文件
#       logging/
#         config.data.json
#         config.meta.json
#         handlers.data.json
#         handlers.meta.json
#         __init__.data.json
#         ... 等 1 个文件
#       markdown_it/
#         main.data.json
#         main.meta.json
#         parser_block.data.json
#         parser_block.meta.json
#         parser_core.data.json
#         ... 等 15 个文件
#         common/
#           entities.data.json
#           entities.meta.json
#           html_blocks.data.json
#           html_blocks.meta.json
#           html_re.data.json
#           ... 等 7 个文件
#         helpers/
#           parse_link_destination.data.json
#           parse_link_destination.meta.json
#           parse_link_label.data.json
#           parse_link_label.meta.json
#           parse_link_title.data.json
#           ... 等 3 个文件
#         presets/
#           commonmark.data.json
#           commonmark.meta.json
#           default.data.json
#           default.meta.json
#           zero.data.json
#           ... 等 3 个文件
#         rules_block/
#           blockquote.data.json
#           blockquote.meta.json
#           code.data.json
#           code.meta.json
#           fence.data.json
#           ... 等 21 个文件
#         rules_core/
#           block.data.json
#           block.meta.json
#           inline.data.json
#           inline.meta.json
#           linkify.data.json
#           ... 等 13 个文件
#         rules_inline/
#           autolink.data.json
#           autolink.meta.json
#           backticks.data.json
#           backticks.meta.json
#           balance_pairs.data.json
#           ... 等 27 个文件
#       markupsafe/
#         _native.data.json
#         _native.meta.json
#         _speedups.data.json
#         _speedups.meta.json
#         __init__.data.json
#         ... 等 1 个文件
#       matplotlib/
#         artist.data.json
#         artist.meta.json
#         axis.data.json
#         axis.meta.json
#         backend_bases.data.json
#         ... 等 105 个文件
#         axes/
#           _axes.data.json
#           _axes.meta.json
#           _base.data.json
#           _base.meta.json
#           _secondary_axes.data.json
#           ... 等 3 个文件
#         backends/
#           registry.data.json
#           registry.meta.json
#           __init__.data.json
#           __init__.meta.json
#         projections/
#           geo.data.json
#           geo.meta.json
#           polar.data.json
#           polar.meta.json
#           __init__.data.json
#           ... 等 1 个文件
#         style/
#           core.data.json
#           core.meta.json
#           __init__.data.json
#           __init__.meta.json
#         tri/
#           _triangulation.data.json
#           _triangulation.meta.json
#           _tricontour.data.json
#           _tricontour.meta.json
#           _trifinder.data.json
#           ... 等 13 个文件
#         _api/
#           deprecation.data.json
#           deprecation.meta.json
#           __init__.data.json
#           __init__.meta.json
#       mdurl/
#         _decode.data.json
#         _decode.meta.json
#         _encode.data.json
#         _encode.meta.json
#         _format.data.json
#         ... 等 7 个文件
#       multidict/
#         _abc.data.json
#         _abc.meta.json
#         _compat.data.json
#         _compat.meta.json
#         _multidict_py.data.json
#         ... 等 3 个文件
#       multiprocessing/
#         connection.data.json
#         connection.meta.json
#         context.data.json
#         context.meta.json
#         managers.data.json
#         ... 等 31 个文件
#       nbformat/
#         converter.data.json
#         converter.meta.json
#         json_compat.data.json
#         json_compat.meta.json
#         notebooknode.data.json
#         ... 等 17 个文件
#         corpus/
#           words.data.json
#           words.meta.json
#           __init__.data.json
#           __init__.meta.json
#         v1/
#           convert.data.json
#           convert.meta.json
#           nbbase.data.json
#           nbbase.meta.json
#           nbjson.data.json
#           ... 等 5 个文件
#         v2/
#           convert.data.json
#           convert.meta.json
#           nbbase.data.json
#           nbbase.meta.json
#           nbjson.data.json
#           ... 等 9 个文件
#         v3/
#           convert.data.json
#           convert.meta.json
#           nbbase.data.json
#           nbbase.meta.json
#           nbjson.data.json
#           ... 等 7 个文件
#         v4/
#           convert.data.json
#           convert.meta.json
#           nbbase.data.json
#           nbbase.meta.json
#           nbjson.data.json
#           ... 等 5 个文件
#       numpy/
#         ctypeslib.data.json
#         ctypeslib.meta.json
#         dtypes.data.json
#         dtypes.meta.json
#         exceptions.data.json
#         ... 等 17 个文件
#         char/
#           __init__.data.json
#           __init__.meta.json
#         core/
#           __init__.data.json
#           __init__.meta.json
#         f2py/
#           __init__.data.json
#           __init__.meta.json
#         fft/
#           _helper.data.json
#           _helper.meta.json
#           _pocketfft.data.json
#           _pocketfft.meta.json
#           __init__.data.json
#           ... 等 1 个文件
#         lib/
#           array_utils.data.json
#           array_utils.meta.json
#           format.data.json
#           format.meta.json
#           introspect.data.json
#           ... 等 49 个文件
#         linalg/
#           _linalg.data.json
#           _linalg.meta.json
#           __init__.data.json
#           __init__.meta.json
#         ma/
#           core.data.json
#           core.meta.json
#           extras.data.json
#           extras.meta.json
#           mrecords.data.json
#           ... 等 3 个文件
#         matrixlib/
#           defmatrix.data.json
#           defmatrix.meta.json
#           __init__.data.json
#           __init__.meta.json
#         polynomial/
#           chebyshev.data.json
#           chebyshev.meta.json
#           hermite.data.json
#           hermite.meta.json
#           hermite_e.data.json
#           ... 等 15 个文件
#         random/
#           bit_generator.data.json
#           bit_generator.meta.json
#           mtrand.data.json
#           mtrand.meta.json
#           _generator.data.json
#           ... 等 11 个文件
#         rec/
#           __init__.data.json
#           __init__.meta.json
#         strings/
#           __init__.data.json
#           __init__.meta.json
#         testing/
#           overrides.data.json
#           overrides.meta.json
#           __init__.data.json
#           __init__.meta.json
#           _private/
#             utils.data.json
#             utils.meta.json
#             __init__.data.json
#             __init__.meta.json
#         typing/
#           __init__.data.json
#           __init__.meta.json
#         _core/
#           arrayprint.data.json
#           arrayprint.meta.json
#           defchararray.data.json
#           defchararray.meta.json
#           einsumfunc.data.json
#           ... 等 27 个文件
#         _typing/
#           _add_docstring.data.json
#           _add_docstring.meta.json
#           _array_like.data.json
#           _array_like.meta.json
#           _callable.data.json
#           ... 等 21 个文件
#         _utils/
#           _convertions.data.json
#           _convertions.meta.json
#           __init__.data.json
#           __init__.meta.json
#       optree/
#         accessors.data.json
#         accessors.meta.json
#         dataclasses.data.json
#         dataclasses.meta.json
#         functools.data.json
#         ... 等 19 个文件
#         integrations/
#           jax.data.json
#           jax.meta.json
#           numpy.data.json
#           numpy.meta.json
#           torch.data.json
#           ... 等 3 个文件
#       optuna/
#         distributions.data.json
#         distributions.meta.json
#         exceptions.data.json
#         exceptions.meta.json
#         logging.data.json
#         ... 等 21 个文件
#         integration/
#           botorch.data.json
#           botorch.meta.json
#           catboost.data.json
#           catboost.meta.json
#           chainer.data.json
#           ... 等 41 个文件
#           allennlp/
#             __init__.data.json
#             __init__.meta.json
#         pruners/
#           _base.data.json
#           _base.meta.json
#           _hyperband.data.json
#           _hyperband.meta.json
#           _median.data.json
#           ... 等 15 个文件
#         samplers/
#           _base.data.json
#           _base.meta.json
#           _brute_force.data.json
#           _brute_force.meta.json
#           _cmaes.data.json
#           ... 等 13 个文件
#           nsgaii/
#             _after_trial_strategy.data.json
#             _after_trial_strategy.meta.json
#             _child_generation_strategy.data.json
#             _child_generation_strategy.meta.json
#             _constraints_evaluation.data.json
#             ... 等 9 个文件
#             _crossovers/
#               _base.data.json
#               _base.meta.json
#               _blxalpha.data.json
#               _blxalpha.meta.json
#               _sbx.data.json
#               ... 等 11 个文件
#           _ga/
#             _base.data.json
#             _base.meta.json
#             __init__.data.json
#             __init__.meta.json
#           _gp/
#             sampler.data.json
#             sampler.meta.json
#             __init__.data.json
#             __init__.meta.json
#           _nsgaiii/
#             _elite_population_selection_strategy.data.json
#             _elite_population_selection_strategy.meta.json
#             _sampler.data.json
#             _sampler.meta.json
#             __init__.data.json
#             ... 等 1 个文件
#           _tpe/
#             parzen_estimator.data.json
#             parzen_estimator.meta.json
#             probability_distributions.data.json
#             probability_distributions.meta.json
#             sampler.data.json
#             ... 等 7 个文件
#         search_space/
#           group_decomposed.data.json
#           group_decomposed.meta.json
#           intersection.data.json
#           intersection.meta.json
#           __init__.data.json
#           ... 等 1 个文件
#         storages/
#           _base.data.json
#           _base.meta.json
#           _cached_storage.data.json
#           _cached_storage.meta.json
#           _callbacks.data.json
#           ... 等 7 个文件
#           journal/
#             _base.data.json
#             _base.meta.json
#             _file.data.json
#             _file.meta.json
#             _redis.data.json
#             ... 等 5 个文件
#           _grpc/
#             auto_generated.data.json
#             auto_generated.meta.json
#             client.data.json
#             client.meta.json
#             server.data.json
#             ... 等 5 个文件
#             auto_generated/
#               api_pb2.data.json
#               api_pb2.meta.json
#               api_pb2_grpc.data.json
#               api_pb2_grpc.meta.json
#           _rdb/
#             models.data.json
#             models.meta.json
#             storage.data.json
#             storage.meta.json
#             __init__.data.json
#             ... 等 1 个文件
#         study/
#           study.data.json
#           study.meta.json
#           _constrained_optimization.data.json
#           _constrained_optimization.meta.json
#           _dataframe.data.json
#           ... 等 15 个文件
#         trial/
#           _base.data.json
#           _base.meta.json
#           _fixed.data.json
#           _fixed.meta.json
#           _frozen.data.json
#           ... 等 7 个文件
#         _gp/
#           acqf.data.json
#           acqf.meta.json
#           batched_lbfgsb.data.json
#           batched_lbfgsb.meta.json
#           gp.data.json
#           ... 等 11 个文件
#         _hypervolume/
#           box_decomposition.data.json
#           box_decomposition.meta.json
#           hssp.data.json
#           hssp.meta.json
#           wfg.data.json
#           ... 等 3 个文件
#       os/
#         path.data.json
#         path.meta.json
#         __init__.data.json
#         __init__.meta.json
#       packaging/
#         markers.data.json
#         markers.meta.json
#         requirements.data.json
#         requirements.meta.json
#         specifiers.data.json
#         ... 等 21 个文件
#       pathlib/
#         __init__.data.json
#         __init__.meta.json
#       PIL/
#         ExifTags.data.json
#         ExifTags.meta.json
#         features.data.json
#         features.meta.json
#         GimpGradientFile.data.json
#         ... 等 53 个文件
#       prompt_toolkit/
#         auto_suggest.data.json
#         auto_suggest.meta.json
#         buffer.data.json
#         buffer.meta.json
#         cache.data.json
#         ... 等 29 个文件
#         application/
#           application.data.json
#           application.meta.json
#           current.data.json
#           current.meta.json
#           dummy.data.json
#           ... 等 5 个文件
#         clipboard/
#           base.data.json
#           base.meta.json
#           in_memory.data.json
#           in_memory.meta.json
#           __init__.data.json
#           ... 等 1 个文件
#         completion/
#           base.data.json
#           base.meta.json
#           deduplicate.data.json
#           deduplicate.meta.json
#           filesystem.data.json
#           ... 等 9 个文件
#         eventloop/
#           async_generator.data.json
#           async_generator.meta.json
#           inputhook.data.json
#           inputhook.meta.json
#           utils.data.json
#           ... 等 3 个文件
#         filters/
#           app.data.json
#           app.meta.json
#           base.data.json
#           base.meta.json
#           cli.data.json
#           ... 等 5 个文件
#         formatted_text/
#           ansi.data.json
#           ansi.meta.json
#           base.data.json
#           base.meta.json
#           html.data.json
#           ... 等 7 个文件
#         input/
#           ansi_escape_sequences.data.json
#           ansi_escape_sequences.meta.json
#           base.data.json
#           base.meta.json
#           defaults.data.json
#           ... 等 7 个文件
#         key_binding/
#           defaults.data.json
#           defaults.meta.json
#           digraphs.data.json
#           digraphs.meta.json
#           emacs_state.data.json
#           ... 等 9 个文件
#           bindings/
#             auto_suggest.data.json
#             auto_suggest.meta.json
#             basic.data.json
#             basic.meta.json
#             completion.data.json
#             ... 等 21 个文件
#         layout/
#           containers.data.json
#           containers.meta.json
#           controls.data.json
#           controls.meta.json
#           dimension.data.json
#           ... 等 21 个文件
#         lexers/
#           base.data.json
#           base.meta.json
#           pygments.data.json
#           pygments.meta.json
#           __init__.data.json
#           ... 等 1 个文件
#         output/
#           base.data.json
#           base.meta.json
#           color_depth.data.json
#           color_depth.meta.json
#           defaults.data.json
#           ... 等 9 个文件
#         shortcuts/
#           choice_input.data.json
#           choice_input.meta.json
#           dialogs.data.json
#           dialogs.meta.json
#           prompt.data.json
#           ... 等 5 个文件
#           progress_bar/
#             base.data.json
#             base.meta.json
#             formatters.data.json
#             formatters.meta.json
#             __init__.data.json
#             ... 等 1 个文件
#         styles/
#           base.data.json
#           base.meta.json
#           defaults.data.json
#           defaults.meta.json
#           named_colors.data.json
#           ... 等 9 个文件
#         widgets/
#           base.data.json
#           base.meta.json
#           dialogs.data.json
#           dialogs.meta.json
#           menus.data.json
#           ... 等 5 个文件
#       propcache/
#         api.data.json
#         api.meta.json
#         _helpers.data.json
#         _helpers.meta.json
#         _helpers_py.data.json
#         ... 等 3 个文件
#       pure_eval/
#         core.data.json
#         core.meta.json
#         my_getattr_static.data.json
#         my_getattr_static.meta.json
#         utils.data.json
#         ... 等 5 个文件
#       pydantic/
#         aliases.data.json
#         aliases.meta.json
#         annotated_handlers.data.json
#         annotated_handlers.meta.json
#         class_validators.data.json
#         ... 等 45 个文件
#         deprecated/
#           class_validators.data.json
#           class_validators.meta.json
#           config.data.json
#           config.meta.json
#           copy_internals.data.json
#           ... 等 9 个文件
#         plugin/
#           _schema_validator.data.json
#           _schema_validator.meta.json
#           __init__.data.json
#           __init__.meta.json
#         v1/
#           annotated_types.data.json
#           annotated_types.meta.json
#           class_validators.data.json
#           class_validators.meta.json
#           color.data.json
#           ... 等 41 个文件
#         _internal/
#           _config.data.json
#           _config.meta.json
#           _core_metadata.data.json
#           _core_metadata.meta.json
#           _core_utils.data.json
#           ... 等 51 个文件
#       pydantic_core/
#         core_schema.data.json
#         core_schema.meta.json
#         _pydantic_core.data.json
#         _pydantic_core.meta.json
#         __init__.data.json
#         ... 等 1 个文件
#       pyexpat/
#         errors.data.json
#         errors.meta.json
#         model.data.json
#         model.meta.json
#         __init__.data.json
#         ... 等 1 个文件
#       pyparsing/
#         actions.data.json
#         actions.meta.json
#         common.data.json
#         common.meta.json
#         core.data.json
#         ... 等 15 个文件
#         diagram/
#           __init__.data.json
#           __init__.meta.json
#       python_multipart/
#         decoders.data.json
#         decoders.meta.json
#         exceptions.data.json
#         exceptions.meta.json
#         multipart.data.json
#         ... 等 3 个文件
#       requests/
#         adapters.data.json
#         adapters.meta.json
#         api.data.json
#         api.meta.json
#         auth.data.json
#         ... 等 25 个文件
#       rich/
#         abc.data.json
#         abc.meta.json
#         align.data.json
#         align.meta.json
#         ansi.data.json
#         ... 等 131 个文件
#       safetensors/
#         flax.data.json
#         flax.meta.json
#         numpy.data.json
#         numpy.meta.json
#         tensorflow.data.json
#         ... 等 5 个文件
#       sniffio/
#         _impl.data.json
#         _impl.meta.json
#         _version.data.json
#         _version.meta.json
#         __init__.data.json
#         ... 等 1 个文件
#       soupsieve/
#         css_match.data.json
#         css_match.meta.json
#         css_parser.data.json
#         css_parser.meta.json
#         css_types.data.json
#         ... 等 9 个文件
#       spacy/
#         about.data.json
#         about.meta.json
#         compat.data.json
#         compat.meta.json
#         errors.data.json
#         ... 等 29 个文件
#         cli/
#           apply.data.json
#           apply.meta.json
#           assemble.data.json
#           assemble.meta.json
#           benchmark_speed.data.json
#           ... 等 39 个文件
#           project/
#             assets.data.json
#             assets.meta.json
#             clone.data.json
#             clone.meta.json
#             document.data.json
#             ... 等 11 个文件
#         displacy/
#           render.data.json
#           render.meta.json
#           templates.data.json
#           templates.meta.json
#           __init__.data.json
#           ... 等 1 个文件
#         kb/
#           __init__.data.json
#           __init__.meta.json
#         lang/
#           char_classes.data.json
#           char_classes.meta.json
#           punctuation.data.json
#           punctuation.meta.json
#           tokenizer_exceptions.data.json
#           ... 等 3 个文件
#           en/
#             lemmatizer.data.json
#             lemmatizer.meta.json
#             lex_attrs.data.json
#             lex_attrs.meta.json
#             punctuation.data.json
#             ... 等 9 个文件
#           xx/
#             __init__.data.json
#             __init__.meta.json
#         matcher/
#           dependencymatcher.data.json
#           dependencymatcher.meta.json
#           matcher.data.json
#           matcher.meta.json
#           phrasematcher.data.json
#           ... 等 3 个文件
#         ml/
#           callbacks.data.json
#           callbacks.meta.json
#           extract_ngrams.data.json
#           extract_ngrams.meta.json
#           extract_spans.data.json
#           ... 等 13 个文件
#           models/
#             entity_linker.data.json
#             entity_linker.meta.json
#             multi_task.data.json
#             multi_task.meta.json
#             parser.data.json
#             ... 等 13 个文件
#         pipeline/
#           attributeruler.data.json
#           attributeruler.meta.json
#           edit_tree_lemmatizer.data.json
#           edit_tree_lemmatizer.meta.json
#           entityruler.data.json
#           ... 等 25 个文件
#           legacy/
#             entity_linker.data.json
#             entity_linker.meta.json
#             __init__.data.json
#             __init__.meta.json
#           _edit_tree_internals/
#             schemas.data.json
#             schemas.meta.json
#             __init__.data.json
#             __init__.meta.json
#           _parser_internals/
#             __init__.data.json
#             __init__.meta.json
#         tokens/
#           doc.data.json
#           doc.meta.json
#           morphanalysis.data.json
#           morphanalysis.meta.json
#           span.data.json
#           ... 等 15 个文件
#         training/
#           alignment.data.json
#           alignment.meta.json
#           augment.data.json
#           augment.meta.json
#           batchers.data.json
#           ... 等 19 个文件
#           converters/
#             conllu_to_docs.data.json
#             conllu_to_docs.meta.json
#             conll_ner_to_docs.data.json
#             conll_ner_to_docs.meta.json
#             iob_to_docs.data.json
#             ... 等 5 个文件
#       sqlalchemy/
#         exc.data.json
#         exc.meta.json
#         inspection.data.json
#         inspection.meta.json
#         log.data.json
#         ... 等 7 个文件
#         connectors/
#           aioodbc.data.json
#           aioodbc.meta.json
#           asyncio.data.json
#           asyncio.meta.json
#           pyodbc.data.json
#           ... 等 3 个文件
#         dialects/
#           _typing.data.json
#           _typing.meta.json
#           __init__.data.json
#           __init__.meta.json
#           mssql/
#             aioodbc.data.json
#             aioodbc.meta.json
#             base.data.json
#             base.meta.json
#             information_schema.data.json
#             ... 等 9 个文件
#           mysql/
#             aiomysql.data.json
#             aiomysql.meta.json
#             asyncmy.data.json
#             asyncmy.meta.json
#             base.data.json
#             ... 等 31 个文件
#           oracle/
#             base.data.json
#             base.meta.json
#             cx_oracle.data.json
#             cx_oracle.meta.json
#             dictionary.data.json
#             ... 等 9 个文件
#           postgresql/
#             array.data.json
#             array.meta.json
#             asyncpg.data.json
#             asyncpg.meta.json
#             base.data.json
#             ... 等 31 个文件
#           sqlite/
#             aiosqlite.data.json
#             aiosqlite.meta.json
#             base.data.json
#             base.meta.json
#             dml.data.json
#             ... 等 9 个文件
#         engine/
#           base.data.json
#           base.meta.json
#           characteristics.data.json
#           characteristics.meta.json
#           create.data.json
#           ... 等 33 个文件
#         event/
#           api.data.json
#           api.meta.json
#           attr.data.json
#           attr.meta.json
#           base.data.json
#           ... 等 7 个文件
#         ext/
#           compiler.data.json
#           compiler.meta.json
#           __init__.data.json
#           __init__.meta.json
#           asyncio/
#             base.data.json
#             base.meta.json
#             engine.data.json
#             engine.meta.json
#             exc.data.json
#             ... 等 9 个文件
#           declarative/
#             extensions.data.json
#             extensions.meta.json
#             __init__.data.json
#             __init__.meta.json
#         future/
#           engine.data.json
#           engine.meta.json
#           __init__.data.json
#           __init__.meta.json
#         orm/
#           attributes.data.json
#           attributes.meta.json
#           base.data.json
#           base.meta.json
#           bulk_persistence.data.json
#           ... 等 71 个文件
#         pool/
#           base.data.json
#           base.meta.json
#           events.data.json
#           events.meta.json
#           impl.data.json
#           ... 等 3 个文件
#         sql/
#           annotation.data.json
#           annotation.meta.json
#           base.data.json
#           base.meta.json
#           cache_key.data.json
#           ... 等 57 个文件
#         util/
#           compat.data.json
#           compat.meta.json
#           concurrency.data.json
#           concurrency.meta.json
#           deprecations.data.json
#           ... 等 21 个文件
#       sqlite3/
#         dbapi2.data.json
#         dbapi2.meta.json
#         __init__.data.json
#         __init__.meta.json
#       src/
#         utils.data.json
#         utils.meta.json
#         utils/
#           logging_config.data.json
#           logging_config.meta.json
#       stack_data/
#         core.data.json
#         core.meta.json
#         formatting.data.json
#         formatting.meta.json
#         serializing.data.json
#         ... 等 7 个文件
#       starlette/
#         applications.data.json
#         applications.meta.json
#         background.data.json
#         background.meta.json
#         concurrency.data.json
#         ... 等 27 个文件
#         middleware/
#           base.data.json
#           base.meta.json
#           errors.data.json
#           errors.meta.json
#           exceptions.data.json
#           ... 等 3 个文件
#       string/
#         __init__.data.json
#         __init__.meta.json
#       sys/
#         _monitoring.data.json
#         _monitoring.meta.json
#         __init__.data.json
#         __init__.meta.json
#       thinc/
#         about.data.json
#         about.meta.json
#         api.data.json
#         api.meta.json
#         compat.data.json
#         ... 等 19 个文件
#         backends/
#           cupy_ops.data.json
#           cupy_ops.meta.json
#           mps_ops.data.json
#           mps_ops.meta.json
#           ops.data.json
#           ... 等 9 个文件
#         layers/
#           add.data.json
#           add.meta.json
#           array_getitem.data.json
#           array_getitem.meta.json
#           bidirectional.data.json
#           ... 等 131 个文件
#         shims/
#           mxnet.data.json
#           mxnet.meta.json
#           pytorch.data.json
#           pytorch.meta.json
#           pytorch_grad_scaler.data.json
#           ... 等 9 个文件
#       tiktoken/
#         core.data.json
#         core.meta.json
#         load.data.json
#         load.meta.json
#         model.data.json
#         ... 等 5 个文件
#       torch/
#         functional.data.json
#         functional.meta.json
#         hub.data.json
#         hub.meta.json
#         library.data.json
#         ... 等 77 个文件
#         accelerator/
#           _utils.data.json
#           _utils.meta.json
#           __init__.data.json
#           __init__.meta.json
#         amp/
#           autocast_mode.data.json
#           autocast_mode.meta.json
#           grad_scaler.data.json
#           grad_scaler.meta.json
#           __init__.data.json
#           ... 等 1 个文件
#         ao/
#           __init__.data.json
#           __init__.meta.json
#           nn/
#             __init__.data.json
#             __init__.meta.json
#             intrinsic/
#               __init__.data.json
#               __init__.meta.json
#               modules/
#                 fused.data.json
#                 fused.meta.json
#                 __init__.data.json
#                 __init__.meta.json
#               qat/
#                 __init__.data.json
#                 __init__.meta.json
#                 modules/
#                   conv_fused.data.json
#                   conv_fused.meta.json
#                   linear_fused.data.json
#                   linear_fused.meta.json
#                   linear_relu.data.json
#                   ... 等 3 个文件
#               quantized/
#                 __init__.data.json
#                 __init__.meta.json
#                 dynamic/
#                   __init__.data.json
#                   __init__.meta.json
#                   modules/
#                     linear_relu.data.json
#                     linear_relu.meta.json
#                     __init__.data.json
#                     __init__.meta.json
#                 modules/
#                   bn_relu.data.json
#                   bn_relu.meta.json
#                   conv_add.data.json
#                   conv_add.meta.json
#                   conv_relu.data.json
#                   ... 等 5 个文件
#             qat/
#               __init__.data.json
#               __init__.meta.json
#               dynamic/
#                 __init__.data.json
#                 __init__.meta.json
#                 modules/
#                   linear.data.json
#                   linear.meta.json
#                   __init__.data.json
#                   __init__.meta.json
#               modules/
#                 conv.data.json
#                 conv.meta.json
#                 embedding_ops.data.json
#                 embedding_ops.meta.json
#                 linear.data.json
#                 ... 等 3 个文件
#             quantizable/
#               __init__.data.json
#               __init__.meta.json
#               modules/
#                 activation.data.json
#                 activation.meta.json
#                 rnn.data.json
#                 rnn.meta.json
#                 __init__.data.json
#                 ... 等 1 个文件
#             quantized/
#               functional.data.json
#               functional.meta.json
#               __init__.data.json
#               __init__.meta.json
#               dynamic/
#                 __init__.data.json
#                 __init__.meta.json
#                 modules/
#                   conv.data.json
#                   conv.meta.json
#                   linear.data.json
#                   linear.meta.json
#                   rnn.data.json
#                   ... 等 3 个文件
#               modules/
#                 activation.data.json
#                 activation.meta.json
#                 batchnorm.data.json
#                 batchnorm.meta.json
#                 conv.data.json
#                 ... 等 17 个文件
#               reference/
#                 __init__.data.json
#                 __init__.meta.json
#                 modules/
#                   conv.data.json
#                   conv.meta.json
#                   linear.data.json
#                   linear.meta.json
#                   rnn.data.json
# ...
#             image_processing_vitpose.meta.json
#             modeling_vitpose.data.json
#             ... 等 3 个文件
#           vitpose_backbone/
#             configuration_vitpose_backbone.data.json
#             configuration_vitpose_backbone.meta.json
#             modeling_vitpose_backbone.data.json
#             modeling_vitpose_backbone.meta.json
#             __init__.data.json
#             ... 等 1 个文件
#           vits/
#             configuration_vits.data.json
#             configuration_vits.meta.json
#             modeling_vits.data.json
#             modeling_vits.meta.json
#             tokenization_vits.data.json
#             ... 等 3 个文件
#           vit_mae/
#             configuration_vit_mae.data.json
#             configuration_vit_mae.meta.json
#             modeling_tf_vit_mae.data.json
#             modeling_tf_vit_mae.meta.json
#             modeling_vit_mae.data.json
#             ... 等 3 个文件
#           vit_msn/
#             configuration_vit_msn.data.json
#             configuration_vit_msn.meta.json
#             modeling_vit_msn.data.json
#             modeling_vit_msn.meta.json
#             __init__.data.json
#             ... 等 1 个文件
#           vivit/
#             configuration_vivit.data.json
#             configuration_vivit.meta.json
#             image_processing_vivit.data.json
#             image_processing_vivit.meta.json
#             modeling_vivit.data.json
#             ... 等 3 个文件
#           vjepa2/
#             configuration_vjepa2.data.json
#             configuration_vjepa2.meta.json
#             modeling_vjepa2.data.json
#             modeling_vjepa2.meta.json
#             video_processing_vjepa2.data.json
#             ... 等 3 个文件
#           voxtral/
#             configuration_voxtral.data.json
#             configuration_voxtral.meta.json
#             modeling_voxtral.data.json
#             modeling_voxtral.meta.json
#             processing_voxtral.data.json
#             ... 等 3 个文件
#           wav2vec2/
#             configuration_wav2vec2.data.json
#             configuration_wav2vec2.meta.json
#             feature_extraction_wav2vec2.data.json
#             feature_extraction_wav2vec2.meta.json
#             modeling_flax_wav2vec2.data.json
#             ... 等 11 个文件
#           wav2vec2_bert/
#             configuration_wav2vec2_bert.data.json
#             configuration_wav2vec2_bert.meta.json
#             modeling_wav2vec2_bert.data.json
#             modeling_wav2vec2_bert.meta.json
#             processing_wav2vec2_bert.data.json
#             ... 等 3 个文件
#           wav2vec2_conformer/
#             configuration_wav2vec2_conformer.data.json
#             configuration_wav2vec2_conformer.meta.json
#             modeling_wav2vec2_conformer.data.json
#             modeling_wav2vec2_conformer.meta.json
#             __init__.data.json
#             ... 等 1 个文件
#           wav2vec2_phoneme/
#             tokenization_wav2vec2_phoneme.data.json
#             tokenization_wav2vec2_phoneme.meta.json
#             __init__.data.json
#             __init__.meta.json
#           wav2vec2_with_lm/
#             processing_wav2vec2_with_lm.data.json
#             processing_wav2vec2_with_lm.meta.json
#             __init__.data.json
#             __init__.meta.json
#           wavlm/
#             configuration_wavlm.data.json
#             configuration_wavlm.meta.json
#             modeling_wavlm.data.json
#             modeling_wavlm.meta.json
#             __init__.data.json
#             ... 等 1 个文件
#           whisper/
#             configuration_whisper.data.json
#             configuration_whisper.meta.json
#             english_normalizer.data.json
#             english_normalizer.meta.json
#             feature_extraction_whisper.data.json
#             ... 等 17 个文件
#           xcodec/
#             configuration_xcodec.data.json
#             configuration_xcodec.meta.json
#             modeling_xcodec.data.json
#             modeling_xcodec.meta.json
#             __init__.data.json
#             ... 等 1 个文件
#           xglm/
#             configuration_xglm.data.json
#             configuration_xglm.meta.json
#             modeling_flax_xglm.data.json
#             modeling_flax_xglm.meta.json
#             modeling_tf_xglm.data.json
#             ... 等 9 个文件
#           xlm/
#             configuration_xlm.data.json
#             configuration_xlm.meta.json
#             modeling_tf_xlm.data.json
#             modeling_tf_xlm.meta.json
#             modeling_xlm.data.json
#             ... 等 5 个文件
#           xlm_roberta/
#             configuration_xlm_roberta.data.json
#             configuration_xlm_roberta.meta.json
#             modeling_flax_xlm_roberta.data.json
#             modeling_flax_xlm_roberta.meta.json
#             modeling_tf_xlm_roberta.data.json
#             ... 等 9 个文件
#           xlm_roberta_xl/
#             configuration_xlm_roberta_xl.data.json
#             configuration_xlm_roberta_xl.meta.json
#             modeling_xlm_roberta_xl.data.json
#             modeling_xlm_roberta_xl.meta.json
#             __init__.data.json
#             ... 等 1 个文件
#           xlnet/
#             configuration_xlnet.data.json
#             configuration_xlnet.meta.json
#             modeling_tf_xlnet.data.json
#             modeling_tf_xlnet.meta.json
#             modeling_xlnet.data.json
#             ... 等 7 个文件
#           xlstm/
#             __init__.data.json
#             __init__.meta.json
#           xmod/
#             configuration_xmod.data.json
#             configuration_xmod.meta.json
#             modeling_xmod.data.json
#             modeling_xmod.meta.json
#             __init__.data.json
#             ... 等 1 个文件
#           x_clip/
#             configuration_x_clip.data.json
#             configuration_x_clip.meta.json
#             modeling_x_clip.data.json
#             modeling_x_clip.meta.json
#             processing_x_clip.data.json
#             ... 等 3 个文件
#           yolos/
#             configuration_yolos.data.json
#             configuration_yolos.meta.json
#             feature_extraction_yolos.data.json
#             feature_extraction_yolos.meta.json
#             image_processing_yolos.data.json
#             ... 等 7 个文件
#           yoso/
#             configuration_yoso.data.json
#             configuration_yoso.meta.json
#             modeling_yoso.data.json
#             modeling_yoso.meta.json
#             __init__.data.json
#             ... 等 1 个文件
#           zamba/
#             configuration_zamba.data.json
#             configuration_zamba.meta.json
#             modeling_zamba.data.json
#             modeling_zamba.meta.json
#             __init__.data.json
#             ... 等 1 个文件
#           zamba2/
#             configuration_zamba2.data.json
#             configuration_zamba2.meta.json
#             modeling_zamba2.data.json
#             modeling_zamba2.meta.json
#             __init__.data.json
#             ... 等 1 个文件
#           zoedepth/
#             configuration_zoedepth.data.json
#             configuration_zoedepth.meta.json
#             image_processing_zoedepth.data.json
#             image_processing_zoedepth.meta.json
#             image_processing_zoedepth_fast.data.json
#             ... 等 5 个文件
#         onnx/
#           config.data.json
#           config.meta.json
#           convert.data.json
#           convert.meta.json
#           features.data.json
#           ... 等 5 个文件
#         pipelines/
#           audio_classification.data.json
#           audio_classification.meta.json
#           audio_utils.data.json
#           audio_utils.meta.json
#           automatic_speech_recognition.data.json
#           ... 等 59 个文件
#         quantizers/
#           auto.data.json
#           auto.meta.json
#           base.data.json
#           base.meta.json
#           quantizers_utils.data.json
#           ... 等 43 个文件
#         utils/
#           auto_docstring.data.json
#           auto_docstring.meta.json
#           backbone_utils.data.json
#           backbone_utils.meta.json
#           chat_template_utils.data.json
#           ... 等 45 个文件
#       typer/
#         colors.data.json
#         colors.meta.json
#         completion.data.json
#         completion.meta.json
#         core.data.json
#         ... 等 21 个文件
#       typing_inspection/
#         introspection.data.json
#         introspection.meta.json
#         typing_objects.data.json
#         typing_objects.meta.json
#         __init__.data.json
#         ... 等 1 个文件
#       unittest/
#         async_case.data.json
#         async_case.meta.json
#         case.data.json
#         case.meta.json
#         loader.data.json
#         ... 等 17 个文件
#       urllib/
#         error.data.json
#         error.meta.json
#         parse.data.json
#         parse.meta.json
#         request.data.json
#         ... 等 5 个文件
#       urllib3/
#         connection.data.json
#         connection.meta.json
#         connectionpool.data.json
#         connectionpool.meta.json
#         exceptions.data.json
#         ... 等 19 个文件
#         contrib/
#           socks.data.json
#           socks.meta.json
#           __init__.data.json
#           __init__.meta.json
#         http2/
#           probe.data.json
#           probe.meta.json
#           __init__.data.json
#           __init__.meta.json
#         util/
#           connection.data.json
#           connection.meta.json
#           proxy.data.json
#           proxy.meta.json
#           request.data.json
#           ... 等 21 个文件
#       wasabi/
#         compat.data.json
#         compat.meta.json
#         markdown.data.json
#         markdown.meta.json
#         printer.data.json
#         ... 等 9 个文件
#       xml/
#         __init__.data.json
#         __init__.meta.json
#         dom/
#           domreg.data.json
#           domreg.meta.json
#           minicompat.data.json
#           minicompat.meta.json
#           minidom.data.json
#           ... 等 5 个文件
#         etree/
#           ElementTree.data.json
#           ElementTree.meta.json
#           __init__.data.json
#           __init__.meta.json
#         parsers/
#           __init__.data.json
#           __init__.meta.json
#           expat/
#             __init__.data.json
#             __init__.meta.json
#         sax/
#           handler.data.json
#           handler.meta.json
#           xmlreader.data.json
#           xmlreader.meta.json
#           _exceptions.data.json
#           ... 等 3 个文件
#       yarl/
#         _parse.data.json
#         _parse.meta.json
#         _path.data.json
#         _path.meta.json
#         _query.data.json
#         ... 等 11 个文件
#       zipfile/
#         __init__.data.json
#         __init__.meta.json
#         _path/
#           __init__.data.json
#           __init__.meta.json
#       zoneinfo/
#         _common.data.json
#         _common.meta.json
#         _tzpath.data.json
#         _tzpath.meta.json
#         __init__.data.json
#         ... 等 1 个文件
#       _typeshed/
#         importlib.data.json
#         importlib.meta.json
#         xml.data.json
#         xml.meta.json
#         __init__.data.json
#         ... 等 1 个文件
#   .pytest_cache/
#     .gitignore
#     CACHEDIR.TAG
#     README.md
#     v/
#       cache/
#         lastfailed
#         nodeids
#   config/
#     config.yaml
#     default_config.yaml
#   data/
#     external/
#     processed/
#       cleaned_movie_data.csv
#       cleaned_movie_data_large.csv
#       cleaned_sample_movie_data.csv
#       feature_engineered_data.csv
#     raw/
#       credits.csv
#       keywords.csv
#       links.csv
#       links_small.csv
#       ml-1m.zip
#       ... 等 8 个文件
#       ml-1m/
#         movies.dat
#         ratings.dat
#         README
#         users.dat
#   logs/
#     movie_analysis_20251209.log
#     movie_analysis_20251210.log
#   notebooks/
#     01_data_acquisition.html
#     01_data_acquisition.ipynb
#     01_data_acquisition.nbconvert.ipynb
#     01_data_acquisition_fixed.ipynb
#     02_data_preprocessing.ipynb
#     ... 等 17 个文件
#     results/
#       result_1/
#         charts/
#   results/
#     data_analysis_method_manual.md
#     LightGBM_feature_importance.png
#     project_analysis_manual.md
#     cache/
#       0060cdd4e3ea27d5dbb3f6fcd8396160.pkl
#       04f4db022d2237089aacd45f5303bb17f2b56658ff68e17bf601dfd958fde057.pkl
#       05a7feb36f65ed1aba18d12221801fc2.pkl
#       16c48c2e8bb844d0920029cf19c4ddf611fdb0df17e2d146a385bb7ae5bed907.pkl
#       204f504f62ec2d449ba1409a81dba481.pkl
#       ... 等 31 个文件
#     charts/
#       basic_budget_vs_revenue.png
#       basic_genre_distribution.png
#       basic_revenue_distribution.png
#       cnn_network_actual_vs_predicted.png
#       cnn_network_training_history.png
#       ... 等 23 个文件
#     models/
#       CNN Network_best.h5
#       CNN Network_history.npy
#       cnn_network_model.h5
#       deep_learning_scaler_x.joblib
#       deep_learning_scaler_y.joblib
#       ... 等 24 个文件
#     model_explanations/
#       Gradient Boosting_lime_0.csv
#       Gradient Boosting_lime_1.csv
#       Gradient Boosting_lime_2.csv
#       Gradient Boosting_shap_values.npy
#       LightGBM_lime_0.csv
#       ... 等 25 个文件
#     reports/
#       data_quality_report.csv
#       missing_values_report.csv
#       model_comparison_metrics.csv
#       model_r2_comparison.png
#       model_rmse_comparison.png
#       ... 等 1 个文件
#     result_1/
#       charts/
#     result_2/
#       charts/
#         revenue_boxplot.png
#         revenue_distribution.png
#     result_3/
#       charts/
#         budget_vs_revenue.png
#         budget_vs_roi.png
#         correlation_heatmap.png
#         genre_counts.png
#         genre_vs_rating.png
#         ... 等 11 个文件
#     result_4/
#       charts/
#     result_5/
#       charts/
#         budget_vs_revenue.png
#         budget_vs_roi.png
#         correlation_heatmap.png
#         genre_counts.png
#         genre_vs_rating.png
#         ... 等 11 个文件
#     result_6/
#       charts/
#         budget_vs_revenue.png
#         budget_vs_roi.png
#         correlation_heatmap.png
#         genre_counts.png
#         genre_vs_rating.png
#         ... 等 11 个文件
#     result_7/
#       charts/
#         budget_vs_revenue.png
#         budget_vs_roi.png
#         clustering_elbow_silhouette.png
#         correlation_heatmap.png
#         genre_counts.png
#         ... 等 13 个文件
#     result_8/
#       charts/
#         budget_vs_revenue.png
#         budget_vs_roi.png
#         clustering_elbow_silhouette.png
#         correlation_heatmap.png
#         genre_counts.png
#         ... 等 13 个文件
#   src/
#     data_acquisition.py
#     deep_learning.py
#     eda_analysis.py
#     feature_engineering.py
#     modeling.py
#     ... 等 6 个文件
#     data/
#       processed/
#     data_preprocessing/
#       data_cleaner.py
#       data_loader.py
#       feature_extractor.py
#       missing_value_handler.py
#       outlier_detector.py
#       ... 等 1 个文件
#       __pycache__/
#         data_cleaner.cpython-313.pyc
#         data_loader.cpython-313.pyc
#         feature_extractor.cpython-313.pyc
#         missing_value_handler.cpython-313.pyc
#         outlier_detector.cpython-313.pyc
#         ... 等 1 个文件
#     scripts/
#       api_deployment.py
#       check_fixed_notebook.py
#       check_notebook.py
#       check_notebooks.py
#       check_text_fields.py
#       ... 等 8 个文件
#     tools/
#       batch_fix_notebooks.py
#       check_notebooks_json.py
#       check_notebooks_nbformat.py
#       check_notebook_strings.py
#       create_fixed_notebook.py
#       ... 等 11 个文件
#     utils/
#       config_manager.py
#       data_validation.py
#       logging_config.py
#       __pycache__/
#         config_manager.cpython-313.pyc
#         data_validation.cpython-313.pyc
#         logging_config.cpython-313.pyc
#     __pycache__/
#       data_preprocessing.cpython-313.pyc
#       deep_learning.cpython-313.pyc
#       eda_analysis.cpython-313.pyc
#       feature_engineering.cpython-313.pyc
#       modeling.cpython-313.pyc
#       ... 等 2 个文件
#   tests/
#     requirements.txt
#     test_data_preprocessing.py
#     test_modeling_features.py
#     test_model_fusion.py
#     test_simple_feature_importance.py
#     __pycache__/
#       test_data_preprocessing.cpython-313-pytest-9.0.2.pyc
#       test_data_preprocessing.cpython-313.pyc
#       test_modeling_features.cpython-313-pytest-9.0.2.pyc
#       test_model_fusion.cpython-313-pytest-9.0.2.pyc
#       test_simple_feature_importance.cpython-313-pytest-9.0.2.pyc
#   __pycache__/
#     main.cpython-313.pyc
#     test_modeling_features.cpython-313-pytest-9.0.2.pyc
#     test_model_fusion.cpython-313-pytest-9.0.2.pyc
#     test_simple_feature_importance.cpython-313-pytest-9.0.2.pyc
#   报告/
#     analysis_conclusion.md
#     data_analysis_method_manual.md
#     LATEST_DATA_GUIDE.md
#     movie_box_office_analysis_report.md
#     movie_box_office_analysis_report_updated.md
#     ... 等 11 个文件

# %% [markdown]
# ## 2. 执行探索性数据分析

# %%
# 导入EDA分析模块
sys.path.insert(0, project_dir)
from src.eda_analysis import EDAnalysis

# 执行探索性数据分析
print('正在执行探索性数据分析...')

# 初始化EDA分析对象
eda_analyzer = EDAnalysis()

# 执行完整的EDA分析
eda_analyzer.run_complete_eda()

print('探索性数据分析完成！')
# Out:
# 2025-12-10 16:53:41,906 - eda_analysis - INFO - 结果将保存到: ./results\result_2
# 2025-12-10 16:53:41,908 - eda_analysis - ERROR - 文件不存在: ./data\processed\cleaned_movie_data.csv
# 2025-12-10 16:53:41,911 - eda_analysis - ERROR - 请先运行数据预处理脚本: python main.py --component preprocess
# 正在执行探索性数据分析...
# 探索性数据分析完成！

# %% [markdown]
# ## 3. 查看生成的图表

# %%
# 查看生成的图表文件
charts_dir = os.path.join(project_dir, 'results', 'charts')
if os.path.exists(charts_dir):
    print('生成的图表文件:')
    for file in os.listdir(charts_dir):
        print(f'  - {file}')
else:
    print('图表目录不存在')
# Out:
# 生成的图表文件:
#   - basic_budget_vs_revenue.png
#   - basic_genre_distribution.png
#   - basic_revenue_distribution.png
#   - cnn_network_actual_vs_predicted.png
#   - cnn_network_training_history.png
#   - deep_model_comparison_r2.png
#   - dense_network_actual_vs_predicted.png
#   - dense_network_training_history.png
#   - gradient_boosting_actual_vs_predicted.png
#   - gradient_boosting_feature_importance.png
#   - gru_network_actual_vs_predicted.png
#   - gru_network_training_history.png
#   - interactive_budget_vs_revenue.html
#   - interactive_top_directors.html
#   - interactive_yearly_trend.html
#   - lightgbm_actual_vs_predicted.png
#   - lightgbm_feature_importance.png
#   - lstm_network_actual_vs_predicted.png
#   - lstm_network_training_history.png
#   - model_comparison_r2.png
#   - model_comparison_rmse.png
#   - movie_box_office_dashboard.py
#   - random_forest_actual_vs_predicted.png
#   - random_forest_feature_importance.png
#   - ridge_regression_actual_vs_predicted.png
#   - ridge_regression_feature_importance.png
#   - xgboost_actual_vs_predicted.png
#   - xgboost_feature_importance.png

# %% [markdown]
# ## 4. 结论

# %%
# 总结探索性数据分析结果
print('探索性数据分析操作完成！')
print('\n下一步操作:')
print('1. 运行04_feature_engineering.ipynb进行特征工程')
print('2. 或使用模块化的FeatureEngineering类在Python代码中调用')
# Out:
# 探索性数据分析操作完成！
#
# 下一步操作:
# 1. 运行04_feature_engineering.ipynb进行特征工程
# 2. 或使用模块化的FeatureEngineering类在Python代码中调用
